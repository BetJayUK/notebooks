# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl 
import seaborn as sns 
import highlight_text as htext
import adjustText as adjust_text

# %%
df2
# Out:
#     Unnamed: 0            Player Pos  ...   90s    Mins  Value
# 8           16  Haris Medunjanin  MF  ...  19.2  1728.0      1
# 23          36        Ján Greguš  MF  ...  17.7  1593.0      1
# 3            4     Álvaro Medrán  MF  ...  22.1  1989.0      1
# 5            7        Jack Price  MF  ...  14.6  1314.0      1
# 40          64       Diego Chará  MF  ...  20.0  1800.0      1
# 43          69   Nicolás Lodeiro  MF  ...  19.8  1782.0      1
#
# [6 rows x 22 columns]

# %%
COLOR = "k"
mpl.rcParams['text.color'] = COLOR
mpl.rcParams['axes.labelcolor'] = "k"
mpl.rcParams['xtick.color'] = "k"
mpl.rcParams['ytick.color'] = COLOR
#mpl.rcParams['title'] = 'k'

fig, ax = plt.subplots(figsize = [10,10])
ax = sns.swarmplot(x="P_SquadPass", 
                        data=df, size = 20)
ax.annotate('Haris Medunjanin', xy=(13.06,0), xytext=(-50, 150),textcoords='offset points',size = 10,
            arrowprops=dict(arrowstyle="-",
                            connectionstyle="arc3,rad=0", color = 'black'))
ax.annotate('Ján Greguš', xy=(12.19,0.012), xytext=(-25, -75),textcoords='offset points',size = 10,
            arrowprops=dict(arrowstyle="-",
                            connectionstyle="arc3,rad=0", color = 'black'))
ax.annotate('Álvaro Medrán', xy=(12.06,-0.08), xytext=(-25, 90),textcoords='offset points',size = 10,
            arrowprops=dict(arrowstyle="-",
                            connectionstyle="arc3,rad=0", color = 'black'))
ax.annotate('Jack Price', xy=(11.97,0.9), xytext=(-55, -100),textcoords='offset points',size = 10,
            arrowprops=dict(arrowstyle="-",
                            connectionstyle="arc3,rad=0", color = 'black'))
ax.annotate('Diego Chará', xy=(11.87,-0.04), xytext=(-55, 150),textcoords='offset points',size = 10,
            arrowprops=dict(arrowstyle="-",
                            connectionstyle="arc3,rad=0", color = 'black'))
ax.annotate('Nicolás Lodeiro', xy=(11.79,0.011), xytext=(-100, 150),textcoords='offset points',size = 10,
            arrowprops=dict(arrowstyle="-",
                            connectionstyle="arc3,rad=0", color = 'black'))
ax = sns.swarmplot(x="P_SquadPass", data = df2, size = 20, color = "red")
ax.set(title = "Major League Soccer 2020: Midfielders with 1000 Minutes or more. ",
       xlabel = "Percentage of Team Passes Per 90")
ax.xaxis.label.set_color("k")
ax.set_facecolor("lightgrey")

# %%
# %matplotlib inline

# %%
5*np.pi
# Out:
# 15.707963267948966
