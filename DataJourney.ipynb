# %% [markdown]
# <a href="https://colab.research.google.com/github/BetJayUK/notebooks/blob/master/DataJourney.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install highlight_text
# Out:
# Collecting highlight_text
#   Downloading https://files.pythonhosted.org/packages/73/ab/d5be20ee7236d6e1582906cef5b0a71e4a79179fa4a2fdae55d721643b3e/highlight_text-0.0.5-py3-none-any.whl
# Installing collected packages: highlight-text
# Successfully installed highlight-text-0.0.5

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl 
import seaborn as sns 
import highlight_text as htext
import adjustText as adjust_text

# %%
df = pd.read_csv('mlsdata.csv')
df1 = df[(df['Mins'] > 1000)]
df2 = df.head(6)

# %%
plt.style.use('seaborn-poster')
#COLOR = "k"
mpl.rcParams['text.color'] = 'w'
#mpl.rcParams['axes.labelcolor'] = "k"
#mpl.rcParams['xtick.color'] = "k"
#mpl.rcParams['ytick.color'] = COLOR
#mpl.rcParams['title'] = 'k'

fig, ax = plt.subplots(figsize = [10,10])
ax = sns.swarmplot(x="P_SquadPass", 
                        data=df, size = 20)
ax.annotate('H. Medunjanin', xy=(13.06,0), xytext=(-55, 50),textcoords='offset points',size = 10,
            arrowprops=dict(arrowstyle="->", 
                            connectionstyle="arc3,rad=0", color = 'w',lw = 1.5))
ax.annotate('J. Greguš', xy=(12.19,0.012), xytext=(-25, -75),textcoords='offset points',size = 10,
            arrowprops=dict(arrowstyle="->",
                            connectionstyle="arc3,rad=0", color = 'w',lw = 1.5))
ax.annotate('Á. Medrán', xy=(12.06,-0.07), xytext=(-23, 90),textcoords='offset points',size = 10,
            arrowprops=dict(arrowstyle="->",
                            connectionstyle="arc3,rad=0", color = 'w',lw = 1.5))
ax.annotate('J. Price', xy=(11.97,0.03), xytext=(-55, -100),textcoords='offset points',size = 10,
            arrowprops=dict(arrowstyle="->",
                            connectionstyle="arc3,rad=0", color = 'w',lw = 1.5))
ax.annotate('D. Chará', xy=(11.87,-0.04), xytext=(-55, 150),textcoords='offset points',size = 10,
            arrowprops=dict(arrowstyle="->",
                            connectionstyle="arc3,rad=0", color = 'w',lw = 1.5))
ax.annotate('N. Lodeiro', xy=(11.73,-0.01), xytext=(-100, 150),textcoords='offset points',size = 10,
            arrowprops=dict(arrowstyle="->",
                            connectionstyle="arc3,rad=0", color = 'w', ls = "-",lw = 1.5))
ax = sns.swarmplot(x="P_SquadPass", data = df2, size = 20, color = "red")
ax.set(xlabel = "Percentage of Team Passes Per 90")
ax.xaxis.label.set_color("w")
ax.set_facecolor("#313332")

background = "#313332"
text_color = 'w'
primary = 'red'
secondary = 'lightblue'
mpl.rcParams['xtick.color'] = text_color
mpl.rcParams['ytick.color'] = text_color
ax.spines['bottom'].set_color('w')
ax.spines['top'].set_color('w') 
ax.spines['right'].set_color('w')
ax.spines['left'].set_color('w')



#Create the text and highlight the different points
s = "Major League Soccer 2020: Finding the Playmaker"
htext.fig_text(s=s,
                x=0.2,y=.9,
                fontfamily='Andale Mono',
                highlight_weights=['bold'],
                #string_weight=['bold']
                fontsize=18,
                color=text_color)
                #highlight_colors=['#a3a3c2','#75a3a3','#ff4d4d','#00cc99'])
fig.patch.set_facecolor(background)
fig.text(.01,0.01,"Twitter: @Jay_RSP\ndata: fbref \nInspiration from: scandinavianfootballanalysis.com",fontstyle='italic',fontsize=9,fontfamily='Andale Mono',color=text_color)

fig, ax = plt.subplots(figsize = [10,10])
ax1 = sns.swarmplot(x="PPN", 
                        data=df, size = 20)
ax.set(xlabel = "Passes Per 90 Minutes")
ax.xaxis.label.set_color("w")
ax.set_facecolor("#313332")
ax1 = sns.swarmplot(x="PPN", data = DFPPN1, size = 20, color = "red")
background = "#313332"
text_color = 'w'
primary = 'red'
secondary = 'lightblue'
mpl.rcParams['xtick.color'] = text_color
mpl.rcParams['ytick.color'] = text_color
ax.spines['bottom'].set_color('w')
ax.spines['top'].set_color('w') 
ax.spines['right'].set_color('w')
ax.spines['left'].set_color('w')
fig.patch.set_facecolor(background)
ax1.set(xlabel = "Passes per 90 minutes")

s1 = "Major League Soccer 2020: Finding the Playmaker"
htext.fig_text(s=s1,
                x=0.2,y=.9,
                fontfamily='Andale Mono',
                highlight_weights=['bold'],
                #string_weight=['bold']
                fontsize=18,
                color=text_color)
                #highlight_colors=['#a3a3c2','#75a3a3','#ff4d4d','#00cc99'])
fig.patch.set_facecolor(background)
fig.text(.01,0.01,"Twitter: @Jay_RSP\ndata: fbref \nInspiration from: scandinavianfootballanalysis.com",fontstyle='italic',fontsize=9,fontfamily='Andale Mono',color=text_color)
# Out:
# Text(0.01, 0.01, 'Twitter: @Jay_RSP\ndata: fbref \nInspiration from: scandinavianfootballanalysis.com')

# %%
fig, ax = plt.subplots(figsize = [10,10])
ax = sns.swarmplot(x="PPN", 
                        data=df, size = 20)

# %%
DFPPN = df.sort_values(by='PPN', ascending=False)
DFPPN1 = DFPPN.head(8)

# %%
  for style in plt.style.available:
    print(style)
# Out:
# Solarize_Light2
# _classic_test_patch
# bmh
# classic
# dark_background
# fast
# fivethirtyeight
# ggplot
# grayscale
# seaborn
# seaborn-bright
# seaborn-colorblind
# seaborn-dark
# seaborn-dark-palette
# seaborn-darkgrid
# seaborn-deep
# seaborn-muted
# seaborn-notebook
# seaborn-paper
# seaborn-pastel
# seaborn-poster
# seaborn-talk
# seaborn-ticks
# seaborn-white
# seaborn-whitegrid
# tableau-colorblind